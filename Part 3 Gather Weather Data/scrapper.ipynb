# %%
import requests
import json
from datetime import datetime, timedelta
import pytz
import time
import os
import csv

def fetch_weather_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL: {url} - {e}")
        return None

def extract_json_data(html_content):
    start_index = html_content.find('<script id="app-root-state" type="application/json">')
    if start_index == -1:
        return None
    start_index += len('<script id="app-root-state" type="application/json">')
    end_index = html_content.find('</script>', start_index)
    if end_index == -1:
        return None
    json_string = html_content[start_index:end_index]
    try:
        return json.loads(json_string)
    except json.JSONDecodeError:
        print("Error decoding JSON")
        return None

def analyze_weather_for_school_hours(json_data, date_str):
    la_timezone = pytz.timezone('America/Los_Angeles')
    school_start_time = la_timezone.localize(datetime.strptime(f"{date_str} 08:00:00", "%Y-%m-%d %H:%M:%S"))
    school_end_time = la_timezone.localize(datetime.strptime(f"{date_str} 15:00:00", "%Y-%m-%d %H:%M:%S"))
    daily_data = []

    if "39526823" in json_data and "b" in json_data["39526823"] and "observations" in json_data["39526823"]["b"]:
        for obs in json_data["39526823"]["b"]["observations"]:
            obs_time_local_str = obs.get("obsTimeLocal")
            if obs_time_local_str:
                try:
                    obs_time_local = datetime.strptime(obs_time_local_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=la_timezone)
                    if school_start_time <= obs_time_local <= school_end_time:
                        temperature = obs.get("imperial", {}).get("temp")
                        condition = obs.get("wxPhraseShort", None)
                        precip_rate = obs.get("imperial", {}).get("precipRate", 0)
                        rain = "yes" if precip_rate > 0 else "no"
                        daily_data.append({
                            "temperature": temperature,
                            "condition": condition,
                            "rain": rain
                        })
                except ValueError as e:
                    print(f"Error parsing time string: {obs_time_local_str} - {e}")

    if "71113034" in json_data and "b" in json_data["71113034"] and "daypart" in json_data["71113034"]["b"]:
        for part in json_data["71113034"]["b"]["daypart"]:
            narratives = part.get("narrative", [])
            temperatures = part.get("temperature", [])
            precip_chances = part.get("precipChance", [])
            times_of_day = part.get("daypartName", [])

            for i in range(len(times_of_day)):
                period_name = times_of_day[i]
                narrative = narratives[i] if i < len(narratives) else None
                temp = temperatures[i] if i < len(temperatures) else None
                precip_chance = precip_chances[i] if i < len(precip_chances) else None

                rain = "yes" if isinstance(precip_chance, (int, float)) and precip_chance > 50 else "no"

                daily_data.append({
                    "temperature": temp,
                    "condition": narrative,
                    "rain": rain
                })

    return daily_data

year = 2024
start_date = datetime(year, 1, 1)
num_days_to_scrape = 366
all_year_data = {}

for i in range(num_days_to_scrape):
    current_date = start_date + timedelta(days=i)
    date_str = current_date.strftime("%Y-%m-%d")
    url = f"https://www.wunderground.com/history/daily/us/ca/hawthorne/KHHR/date/{date_str}"
    print(f"Fetching data for {date_str}...")
    html_content = fetch_weather_data(url)
    if html_content:
        json_data = extract_json_data(html_content)
        if json_data:
            print(f"Analyzing weather for {date_str}...")
            daily_school_hours_data = analyze_weather_for_school_hours(json_data, date_str)
            all_year_data[date_str] = daily_school_hours_data
        else:
            print(f"Could not extract JSON data for {date_str}")
    else:
        print(f"Failed to fetch data for {date_str}")
    time.sleep(1)

os.makedirs("data", exist_ok=True)
csv_path = os.path.join("data", "weather_data_hourly.csv")

with open(csv_path, mode="w", newline="") as csv_file:
    fieldnames = ["Date", "Temperature", "Condition", "Rain (yes/no)"]
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for date, entries in all_year_data.items():
        for entry in entries:
            writer.writerow({
                "Date": date,
                "Temperature": entry.get("temperature"),
                "Condition": entry.get("condition"),
                "Rain (yes/no)": entry.get("rain")
            })

print(f"\nCSV saved at: {csv_path}")
# Out:
# Fetching data for 2024-01-01...
# Analyzing weather for 2024-01-01...
# Fetching data for 2024-01-02...
# Analyzing weather for 2024-01-02...
# Fetching data for 2024-01-03...
# Analyzing weather for 2024-01-03...
# Fetching data for 2024-01-04...
# Analyzing weather for 2024-01-04...
# Fetching data for 2024-01-05...
# Analyzing weather for 2024-01-05...
# Fetching data for 2024-01-06...
# Analyzing weather for 2024-01-06...
# Fetching data for 2024-01-07...
# Analyzing weather for 2024-01-07...
# Fetching data for 2024-01-08...
# Analyzing weather for 2024-01-08...
# Fetching data for 2024-01-09...
# Analyzing weather for 2024-01-09...
# Fetching data for 2024-01-10...
# Analyzing weather for 2024-01-10...
# Fetching data for 2024-01-11...
# Analyzing weather for 2024-01-11...
# Fetching data for 2024-01-12...
# Analyzing weather for 2024-01-12...
# Fetching data for 2024-01-13...
# Analyzing weather for 2024-01-13...
# Fetching data for 2024-01-14...
# Analyzing weather for 2024-01-14...
# Fetching data for 2024-01-15...
# Analyzing weather for 2024-01-15...
# Fetching data for 2024-01-16...
# Analyzing weather for 2024-01-16...
# Fetching data for 2024-01-17...
# Analyzing weather for 2024-01-17...
# Fetching data for 2024-01-18...
# Analyzing weather for 2024-01-18...
# Fetching data for 2024-01-19...
# Analyzing weather for 2024-01-19...
# Fetching data for 2024-01-20...
# Analyzing weather for 2024-01-20...
# Fetching data for 2024-01-21...
# Analyzing weather for 2024-01-21...
# Fetching data for 2024-01-22...
# Analyzing weather for 2024-01-22...
# Fetching data for 2024-01-23...
# Analyzing weather for 2024-01-23...
# Fetching data for 2024-01-24...
# Analyzing weather for 2024-01-24...
# Fetching data for 2024-01-25...
# Analyzing weather for 2024-01-25...
# Fetching data for 2024-01-26...
# Analyzing weather for 2024-01-26...
# Fetching data for 2024-01-27...
# Analyzing weather for 2024-01-27...
# Fetching data for 2024-01-28...
# Analyzing weather for 2024-01-28...
# Fetching data for 2024-01-29...
# Analyzing weather for 2024-01-29...
# Fetching data for 2024-01-30...
# Analyzing weather for 2024-01-30...
# Fetching data for 2024-01-31...
# Analyzing weather for 2024-01-31...
# Fetching data for 2024-02-01...
# Analyzing weather for 2024-02-01...
# Fetching data for 2024-02-02...
# Analyzing weather for 2024-02-02...
# Fetching data for 2024-02-03...
# Analyzing weather for 2024-02-03...
# Fetching data for 2024-02-04...
# Analyzing weather for 2024-02-04...
# Fetching data for 2024-02-05...
# Analyzing weather for 2024-02-05...
# Fetching data for 2024-02-06...
# Analyzing weather for 2024-02-06...
# Fetching data for 2024-02-07...
# Analyzing weather for 2024-02-07...
# Fetching data for 2024-02-08...
# Analyzing weather for 2024-02-08...
# Fetching data for 2024-02-09...
# Analyzing weather for 2024-02-09...
# Fetching data for 2024-02-10...
# Analyzing weather for 2024-02-10...
# Fetching data for 2024-02-11...
# Analyzing weather for 2024-02-11...
# Fetching data for 2024-02-12...
# Analyzing weather for 2024-02-12...
# Fetching data for 2024-02-13...
# Analyzing weather for 2024-02-13...
# Fetching data for 2024-02-14...
# Analyzing weather for 2024-02-14...
# Fetching data for 2024-02-15...
# Analyzing weather for 2024-02-15...
# Fetching data for 2024-02-16...
# Analyzing weather for 2024-02-16...
# Fetching data for 2024-02-17...
# Analyzing weather for 2024-02-17...
# Fetching data for 2024-02-18...
# Analyzing weather for 2024-02-18...
# Fetching data for 2024-02-19...
# Analyzing weather for 2024-02-19...
# Fetching data for 2024-02-20...
# Analyzing weather for 2024-02-20...
# Fetching data for 2024-02-21...
# Analyzing weather for 2024-02-21...
# Fetching data for 2024-02-22...
# Analyzing weather for 2024-02-22...
# Fetching data for 2024-02-23...
# Analyzing weather for 2024-02-23...
# Fetching data for 2024-02-24...
# Analyzing weather for 2024-02-24...
# Fetching data for 2024-02-25...
# Analyzing weather for 2024-02-25...
# Fetching data for 2024-02-26...
# Analyzing weather for 2024-02-26...
# Fetching data for 2024-02-27...
# Analyzing weather for 2024-02-27...
# Fetching data for 2024-02-28...
# Analyzing weather for 2024-02-28...
# Fetching data for 2024-02-29...
# Analyzing weather for 2024-02-29...
# Fetching data for 2024-03-01...
# Analyzing weather for 2024-03-01...
# Fetching data for 2024-03-02...
# Analyzing weather for 2024-03-02...
# Fetching data for 2024-03-03...
# Analyzing weather for 2024-03-03...
# Fetching data for 2024-03-04...
# Analyzing weather for 2024-03-04...
# Fetching data for 2024-03-05...
# Analyzing weather for 2024-03-05...
# Fetching data for 2024-03-06...
# Analyzing weather for 2024-03-06...
# Fetching data for 2024-03-07...
# Analyzing weather for 2024-03-07...
# Fetching data for 2024-03-08...
# Analyzing weather for 2024-03-08...
# Fetching data for 2024-03-09...
# Analyzing weather for 2024-03-09...
# Fetching data for 2024-03-10...
# Analyzing weather for 2024-03-10...
# Fetching data for 2024-03-11...
# Analyzing weather for 2024-03-11...
# Fetching data for 2024-03-12...
# Analyzing weather for 2024-03-12...
# Fetching data for 2024-03-13...
# Analyzing weather for 2024-03-13...
# Fetching data for 2024-03-14...
# Analyzing weather for 2024-03-14...
# Fetching data for 2024-03-15...
# Analyzing weather for 2024-03-15...
# Fetching data for 2024-03-16...
# Analyzing weather for 2024-03-16...
# Fetching data for 2024-03-17...
# Analyzing weather for 2024-03-17...
# Fetching data for 2024-03-18...
# Analyzing weather for 2024-03-18...
# Fetching data for 2024-03-19...
# Analyzing weather for 2024-03-19...
# Fetching data for 2024-03-20...
# Analyzing weather for 2024-03-20...
# Fetching data for 2024-03-21...
# Analyzing weather for 2024-03-21...
# Fetching data for 2024-03-22...
# Analyzing weather for 2024-03-22...
# Fetching data for 2024-03-23...
# Analyzing weather for 2024-03-23...
# Fetching data for 2024-03-24...
# Analyzing weather for 2024-03-24...
# Fetching data for 2024-03-25...
# Analyzing weather for 2024-03-25...
# Fetching data for 2024-03-26...
# Analyzing weather for 2024-03-26...
# Fetching data for 2024-03-27...
# Analyzing weather for 2024-03-27...
# Fetching data for 2024-03-28...
# Analyzing weather for 2024-03-28...
# Fetching data for 2024-03-29...
# Analyzing weather for 2024-03-29...
# Fetching data for 2024-03-30...
# Analyzing weather for 2024-03-30...
# Fetching data for 2024-03-31...
# Analyzing weather for 2024-03-31...
# Fetching data for 2024-04-01...
# Analyzing weather for 2024-04-01...
# Fetching data for 2024-04-02...
# Analyzing weather for 2024-04-02...
# Fetching data for 2024-04-03...
# Analyzing weather for 2024-04-03...
# Fetching data for 2024-04-04...
# Analyzing weather for 2024-04-04...
# Fetching data for 2024-04-05...
# Analyzing weather for 2024-04-05...
# Fetching data for 2024-04-06...
# Analyzing weather for 2024-04-06...
# Fetching data for 2024-04-07...
# Analyzing weather for 2024-04-07...
# Fetching data for 2024-04-08...
# Analyzing weather for 2024-04-08...
# Fetching data for 2024-04-09...
# Analyzing weather for 2024-04-09...
# Fetching data for 2024-04-10...
# Analyzing weather for 2024-04-10...
# Fetching data for 2024-04-11...
# Analyzing weather for 2024-04-11...
# Fetching data for 2024-04-12...
# Analyzing weather for 2024-04-12...
# Fetching data for 2024-04-13...
# Analyzing weather for 2024-04-13...
# Fetching data for 2024-04-14...
# Analyzing weather for 2024-04-14...
# Fetching data for 2024-04-15...
# Analyzing weather for 2024-04-15...
# Fetching data for 2024-04-16...
# Analyzing weather for 2024-04-16...
# Fetching data for 2024-04-17...
# Analyzing weather for 2024-04-17...
# Fetching data for 2024-04-18...
# Analyzing weather for 2024-04-18...
# Fetching data for 2024-04-19...
# Analyzing weather for 2024-04-19...
# Fetching data for 2024-04-20...
# Analyzing weather for 2024-04-20...
# Fetching data for 2024-04-21...
# Analyzing weather for 2024-04-21...
# Fetching data for 2024-04-22...
# Analyzing weather for 2024-04-22...
# Fetching data for 2024-04-23...
# Analyzing weather for 2024-04-23...
# Fetching data for 2024-04-24...
# Analyzing weather for 2024-04-24...
# Fetching data for 2024-04-25...
# Analyzing weather for 2024-04-25...
# Fetching data for 2024-04-26...
# Analyzing weather for 2024-04-26...
# Fetching data for 2024-04-27...
# Analyzing weather for 2024-04-27...
# Fetching data for 2024-04-28...
# Analyzing weather for 2024-04-28...
# Fetching data for 2024-04-29...
# Analyzing weather for 2024-04-29...
# Fetching data for 2024-04-30...
# Analyzing weather for 2024-04-30...
# Fetching data for 2024-05-01...
# Analyzing weather for 2024-05-01...
# Fetching data for 2024-05-02...
# Analyzing weather for 2024-05-02...
# Fetching data for 2024-05-03...
# Analyzing weather for 2024-05-03...
# Fetching data for 2024-05-04...
# Analyzing weather for 2024-05-04...
# Fetching data for 2024-05-05...
# Analyzing weather for 2024-05-05...
# Fetching data for 2024-05-06...
# Analyzing weather for 2024-05-06...
# Fetching data for 2024-05-07...
# Analyzing weather for 2024-05-07...
# Fetching data for 2024-05-08...
# Analyzing weather for 2024-05-08...
# Fetching data for 2024-05-09...
# Analyzing weather for 2024-05-09...
# Fetching data for 2024-05-10...
# Analyzing weather for 2024-05-10...
# Fetching data for 2024-05-11...
# Analyzing weather for 2024-05-11...
# Fetching data for 2024-05-12...
# Analyzing weather for 2024-05-12...
# Fetching data for 2024-05-13...
# Analyzing weather for 2024-05-13...
# Fetching data for 2024-05-14...
# Analyzing weather for 2024-05-14...
# Fetching data for 2024-05-15...
# Analyzing weather for 2024-05-15...
# Fetching data for 2024-05-16...
# Analyzing weather for 2024-05-16...
# Fetching data for 2024-05-17...
# Analyzing weather for 2024-05-17...
# Fetching data for 2024-05-18...
# Analyzing weather for 2024-05-18...
# Fetching data for 2024-05-19...
# Analyzing weather for 2024-05-19...
# Fetching data for 2024-05-20...
# Analyzing weather for 2024-05-20...
# Fetching data for 2024-05-21...
# Analyzing weather for 2024-05-21...
# Fetching data for 2024-05-22...
# Analyzing weather for 2024-05-22...
# Fetching data for 2024-05-23...
# Analyzing weather for 2024-05-23...
# Fetching data for 2024-05-24...
# Analyzing weather for 2024-05-24...
# Fetching data for 2024-05-25...
# Analyzing weather for 2024-05-25...
# Fetching data for 2024-05-26...
# Analyzing weather for 2024-05-26...
# Fetching data for 2024-05-27...
# Analyzing weather for 2024-05-27...
# Fetching data for 2024-05-28...
# Analyzing weather for 2024-05-28...
# Fetching data for 2024-05-29...
# Analyzing weather for 2024-05-29...
# Fetching data for 2024-05-30...
# Analyzing weather for 2024-05-30...
# Fetching data for 2024-05-31...
# Analyzing weather for 2024-05-31...
# Fetching data for 2024-06-01...
# Analyzing weather for 2024-06-01...
# Fetching data for 2024-06-02...
# Analyzing weather for 2024-06-02...
# Fetching data for 2024-06-03...
# Analyzing weather for 2024-06-03...
# Fetching data for 2024-06-04...
# Analyzing weather for 2024-06-04...
# Fetching data for 2024-06-05...
# Analyzing weather for 2024-06-05...
# Fetching data for 2024-06-06...
# Analyzing weather for 2024-06-06...
# Fetching data for 2024-06-07...
# Analyzing weather for 2024-06-07...
# Fetching data for 2024-06-08...
# Analyzing weather for 2024-06-08...
# Fetching data for 2024-06-09...
# Analyzing weather for 2024-06-09...
# Fetching data for 2024-06-10...
# Analyzing weather for 2024-06-10...
# Fetching data for 2024-06-11...
# Analyzing weather for 2024-06-11...
# Fetching data for 2024-06-12...
# Analyzing weather for 2024-06-12...
# Fetching data for 2024-06-13...
# Analyzing weather for 2024-06-13...
# Fetching data for 2024-06-14...
# Analyzing weather for 2024-06-14...
# Fetching data for 2024-06-15...
# Analyzing weather for 2024-06-15...
# Fetching data for 2024-06-16...
# Analyzing weather for 2024-06-16...
# Fetching data for 2024-06-17...
# Analyzing weather for 2024-06-17...
# Fetching data for 2024-06-18...
# Analyzing weather for 2024-06-18...
# Fetching data for 2024-06-19...
# Analyzing weather for 2024-06-19...
# Fetching data for 2024-06-20...
# Analyzing weather for 2024-06-20...
# Fetching data for 2024-06-21...
# Analyzing weather for 2024-06-21...
# Fetching data for 2024-06-22...
# Analyzing weather for 2024-06-22...
# Fetching data for 2024-06-23...
# Analyzing weather for 2024-06-23...
# Fetching data for 2024-06-24...
# Analyzing weather for 2024-06-24...
# Fetching data for 2024-06-25...
# Analyzing weather for 2024-06-25...
# Fetching data for 2024-06-26...
# Analyzing weather for 2024-06-26...
# Fetching data for 2024-06-27...
# Analyzing weather for 2024-06-27...
# Fetching data for 2024-06-28...
# Analyzing weather for 2024-06-28...
# Fetching data for 2024-06-29...
# Analyzing weather for 2024-06-29...
# Fetching data for 2024-06-30...
# Analyzing weather for 2024-06-30...
# Fetching data for 2024-07-01...
# Analyzing weather for 2024-07-01...
# Fetching data for 2024-07-02...
# Analyzing weather for 2024-07-02...
# Fetching data for 2024-07-03...
# Analyzing weather for 2024-07-03...
# Fetching data for 2024-07-04...
# Analyzing weather for 2024-07-04...
# Fetching data for 2024-07-05...
# Analyzing weather for 2024-07-05...
# Fetching data for 2024-07-06...
# Analyzing weather for 2024-07-06...
# Fetching data for 2024-07-07...
# Analyzing weather for 2024-07-07...
# Fetching data for 2024-07-08...
# Analyzing weather for 2024-07-08...
# Fetching data for 2024-07-09...
# Analyzing weather for 2024-07-09...
# Fetching data for 2024-07-10...
# Analyzing weather for 2024-07-10...
# Fetching data for 2024-07-11...
# Analyzing weather for 2024-07-11...
# Fetching data for 2024-07-12...
# Analyzing weather for 2024-07-12...
# Fetching data for 2024-07-13...
# Analyzing weather for 2024-07-13...
# Fetching data for 2024-07-14...
# Analyzing weather for 2024-07-14...
# Fetching data for 2024-07-15...
# Analyzing weather for 2024-07-15...
# Fetching data for 2024-07-16...
# Analyzing weather for 2024-07-16...
# Fetching data for 2024-07-17...
# Analyzing weather for 2024-07-17...
# Fetching data for 2024-07-18...
# Analyzing weather for 2024-07-18...
# Fetching data for 2024-07-19...
# Analyzing weather for 2024-07-19...
# Fetching data for 2024-07-20...
# Analyzing weather for 2024-07-20...
# Fetching data for 2024-07-21...
# Analyzing weather for 2024-07-21...
# Fetching data for 2024-07-22...
# Analyzing weather for 2024-07-22...
# Fetching data for 2024-07-23...
# Analyzing weather for 2024-07-23...
# Fetching data for 2024-07-24...
# Analyzing weather for 2024-07-24...
# Fetching data for 2024-07-25...
# Analyzing weather for 2024-07-25...
# Fetching data for 2024-07-26...
# Analyzing weather for 2024-07-26...
# Fetching data for 2024-07-27...
# Analyzing weather for 2024-07-27...
# Fetching data for 2024-07-28...
# Analyzing weather for 2024-07-28...
# Fetching data for 2024-07-29...
# Analyzing weather for 2024-07-29...
# Fetching data for 2024-07-30...
# Analyzing weather for 2024-07-30...
# Fetching data for 2024-07-31...
# Analyzing weather for 2024-07-31...
# Fetching data for 2024-08-01...
# Analyzing weather for 2024-08-01...
# Fetching data for 2024-08-02...
# Analyzing weather for 2024-08-02...
# Fetching data for 2024-08-03...
# Analyzing weather for 2024-08-03...
# Fetching data for 2024-08-04...
# Analyzing weather for 2024-08-04...
# Fetching data for 2024-08-05...
# Analyzing weather for 2024-08-05...
# Fetching data for 2024-08-06...
# Analyzing weather for 2024-08-06...
# Fetching data for 2024-08-07...
# Analyzing weather for 2024-08-07...
# Fetching data for 2024-08-08...
# Analyzing weather for 2024-08-08...
# Fetching data for 2024-08-09...
# Analyzing weather for 2024-08-09...
# Fetching data for 2024-08-10...
# Analyzing weather for 2024-08-10...
# Fetching data for 2024-08-11...
# Analyzing weather for 2024-08-11...
# Fetching data for 2024-08-12...
# Analyzing weather for 2024-08-12...
# Fetching data for 2024-08-13...
# Analyzing weather for 2024-08-13...
# Fetching data for 2024-08-14...
# Analyzing weather for 2024-08-14...
# Fetching data for 2024-08-15...
# Analyzing weather for 2024-08-15...
# Fetching data for 2024-08-16...
# Analyzing weather for 2024-08-16...
# Fetching data for 2024-08-17...
# Analyzing weather for 2024-08-17...
# Fetching data for 2024-08-18...
# Analyzing weather for 2024-08-18...
# Fetching data for 2024-08-19...
# Analyzing weather for 2024-08-19...
# Fetching data for 2024-08-20...
# Analyzing weather for 2024-08-20...
# Fetching data for 2024-08-21...
# Analyzing weather for 2024-08-21...
# Fetching data for 2024-08-22...
# Analyzing weather for 2024-08-22...
# Fetching data for 2024-08-23...
# Analyzing weather for 2024-08-23...
# Fetching data for 2024-08-24...
# Analyzing weather for 2024-08-24...
# Fetching data for 2024-08-25...
# Analyzing weather for 2024-08-25...
# Fetching data for 2024-08-26...
# Analyzing weather for 2024-08-26...
# Fetching data for 2024-08-27...
# Analyzing weather for 2024-08-27...
# Fetching data for 2024-08-28...
# Analyzing weather for 2024-08-28...
# Fetching data for 2024-08-29...
# Analyzing weather for 2024-08-29...
# Fetching data for 2024-08-30...
# Analyzing weather for 2024-08-30...
# Fetching data for 2024-08-31...
# Analyzing weather for 2024-08-31...
# Fetching data for 2024-09-01...
# Analyzing weather for 2024-09-01...
# Fetching data for 2024-09-02...
# Analyzing weather for 2024-09-02...
# Fetching data for 2024-09-03...
# Analyzing weather for 2024-09-03...
# Fetching data for 2024-09-04...
# Analyzing weather for 2024-09-04...
# Fetching data for 2024-09-05...
# Analyzing weather for 2024-09-05...
# Fetching data for 2024-09-06...
# Analyzing weather for 2024-09-06...
# Fetching data for 2024-09-07...
# Analyzing weather for 2024-09-07...
# Fetching data for 2024-09-08...
# Analyzing weather for 2024-09-08...
# Fetching data for 2024-09-09...
# Analyzing weather for 2024-09-09...
# Fetching data for 2024-09-10...
# Analyzing weather for 2024-09-10...
# Fetching data for 2024-09-11...
# Analyzing weather for 2024-09-11...
# Fetching data for 2024-09-12...
# Analyzing weather for 2024-09-12...
# Fetching data for 2024-09-13...
# Analyzing weather for 2024-09-13...
# Fetching data for 2024-09-14...
# Analyzing weather for 2024-09-14...
# Fetching data for 2024-09-15...
# Analyzing weather for 2024-09-15...
# Fetching data for 2024-09-16...
# Analyzing weather for 2024-09-16...
# Fetching data for 2024-09-17...
# Analyzing weather for 2024-09-17...
# Fetching data for 2024-09-18...
# Analyzing weather for 2024-09-18...
# Fetching data for 2024-09-19...
# Analyzing weather for 2024-09-19...
# Fetching data for 2024-09-20...
# Analyzing weather for 2024-09-20...
# Fetching data for 2024-09-21...
# Analyzing weather for 2024-09-21...
# Fetching data for 2024-09-22...
# Analyzing weather for 2024-09-22...
# Fetching data for 2024-09-23...
# Analyzing weather for 2024-09-23...
# Fetching data for 2024-09-24...
# Analyzing weather for 2024-09-24...
# Fetching data for 2024-09-25...
# Analyzing weather for 2024-09-25...
# Fetching data for 2024-09-26...
# Analyzing weather for 2024-09-26...
# Fetching data for 2024-09-27...
# Analyzing weather for 2024-09-27...
# Fetching data for 2024-09-28...
# Analyzing weather for 2024-09-28...
# Fetching data for 2024-09-29...
# Analyzing weather for 2024-09-29...
# Fetching data for 2024-09-30...
# Analyzing weather for 2024-09-30...
# Fetching data for 2024-10-01...
# Analyzing weather for 2024-10-01...
# Fetching data for 2024-10-02...
# Analyzing weather for 2024-10-02...
# Fetching data for 2024-10-03...
# Analyzing weather for 2024-10-03...
# Fetching data for 2024-10-04...
# Analyzing weather for 2024-10-04...
# Fetching data for 2024-10-05...
# Analyzing weather for 2024-10-05...
# Fetching data for 2024-10-06...
# Analyzing weather for 2024-10-06...
# Fetching data for 2024-10-07...
# Analyzing weather for 2024-10-07...
# Fetching data for 2024-10-08...
# Analyzing weather for 2024-10-08...
# Fetching data for 2024-10-09...
# Analyzing weather for 2024-10-09...
# Fetching data for 2024-10-10...
# Analyzing weather for 2024-10-10...
# Fetching data for 2024-10-11...
# Analyzing weather for 2024-10-11...
# Fetching data for 2024-10-12...
# Analyzing weather for 2024-10-12...
# Fetching data for 2024-10-13...
# Analyzing weather for 2024-10-13...
# Fetching data for 2024-10-14...
# Analyzing weather for 2024-10-14...
# Fetching data for 2024-10-15...
# Analyzing weather for 2024-10-15...
# Fetching data for 2024-10-16...
# Analyzing weather for 2024-10-16...
# Fetching data for 2024-10-17...
# Analyzing weather for 2024-10-17...
# Fetching data for 2024-10-18...
# Analyzing weather for 2024-10-18...
# Fetching data for 2024-10-19...
# Analyzing weather for 2024-10-19...
# Fetching data for 2024-10-20...
# Analyzing weather for 2024-10-20...
# Fetching data for 2024-10-21...
# Analyzing weather for 2024-10-21...
# Fetching data for 2024-10-22...
# Analyzing weather for 2024-10-22...
# Fetching data for 2024-10-23...
# Analyzing weather for 2024-10-23...
# Fetching data for 2024-10-24...
# Analyzing weather for 2024-10-24...
# Fetching data for 2024-10-25...
# Analyzing weather for 2024-10-25...
# Fetching data for 2024-10-26...
# Analyzing weather for 2024-10-26...
# Fetching data for 2024-10-27...
# Analyzing weather for 2024-10-27...
# Fetching data for 2024-10-28...
# Analyzing weather for 2024-10-28...
# Fetching data for 2024-10-29...
# Analyzing weather for 2024-10-29...
# Fetching data for 2024-10-30...
# Analyzing weather for 2024-10-30...
# Fetching data for 2024-10-31...
# Analyzing weather for 2024-10-31...
# Fetching data for 2024-11-01...
# Analyzing weather for 2024-11-01...
# Fetching data for 2024-11-02...
# Analyzing weather for 2024-11-02...
# Fetching data for 2024-11-03...
# Analyzing weather for 2024-11-03...
# Fetching data for 2024-11-04...
# Analyzing weather for 2024-11-04...
# Fetching data for 2024-11-05...
# Analyzing weather for 2024-11-05...
# Fetching data for 2024-11-06...
# Analyzing weather for 2024-11-06...
# Fetching data for 2024-11-07...
# Analyzing weather for 2024-11-07...
# Fetching data for 2024-11-08...
# Analyzing weather for 2024-11-08...
# Fetching data for 2024-11-09...
# Analyzing weather for 2024-11-09...
# Fetching data for 2024-11-10...
# Analyzing weather for 2024-11-10...
# Fetching data for 2024-11-11...
# Analyzing weather for 2024-11-11...
# Fetching data for 2024-11-12...
# Analyzing weather for 2024-11-12...
# Fetching data for 2024-11-13...
# Analyzing weather for 2024-11-13...
# Fetching data for 2024-11-14...
# Analyzing weather for 2024-11-14...
# Fetching data for 2024-11-15...
# Analyzing weather for 2024-11-15...
# Fetching data for 2024-11-16...
# Analyzing weather for 2024-11-16...
# Fetching data for 2024-11-17...
# Analyzing weather for 2024-11-17...
# Fetching data for 2024-11-18...
# Analyzing weather for 2024-11-18...
# Fetching data for 2024-11-19...
# Analyzing weather for 2024-11-19...
# Fetching data for 2024-11-20...
# Analyzing weather for 2024-11-20...
# Fetching data for 2024-11-21...
# Analyzing weather for 2024-11-21...
# Fetching data for 2024-11-22...
# Analyzing weather for 2024-11-22...
# Fetching data for 2024-11-23...
# Analyzing weather for 2024-11-23...
# Fetching data for 2024-11-24...
# Analyzing weather for 2024-11-24...
# Fetching data for 2024-11-25...
# Analyzing weather for 2024-11-25...
# Fetching data for 2024-11-26...
# Analyzing weather for 2024-11-26...
# Fetching data for 2024-11-27...
# Analyzing weather for 2024-11-27...
# Fetching data for 2024-11-28...
# Analyzing weather for 2024-11-28...
# Fetching data for 2024-11-29...
# Analyzing weather for 2024-11-29...
# Fetching data for 2024-11-30...
# Analyzing weather for 2024-11-30...
# Fetching data for 2024-12-01...
# Analyzing weather for 2024-12-01...
# Fetching data for 2024-12-02...
# Analyzing weather for 2024-12-02...
# Fetching data for 2024-12-03...
# Analyzing weather for 2024-12-03...
# Fetching data for 2024-12-04...
# Analyzing weather for 2024-12-04...
# Fetching data for 2024-12-05...
# Analyzing weather for 2024-12-05...
# Fetching data for 2024-12-06...
# Analyzing weather for 2024-12-06...
# Fetching data for 2024-12-07...
# Analyzing weather for 2024-12-07...
# Fetching data for 2024-12-08...
# Analyzing weather for 2024-12-08...
# Fetching data for 2024-12-09...
# Analyzing weather for 2024-12-09...
# Fetching data for 2024-12-10...
# Analyzing weather for 2024-12-10...
# Fetching data for 2024-12-11...
# Analyzing weather for 2024-12-11...
# Fetching data for 2024-12-12...
# Analyzing weather for 2024-12-12...
# Fetching data for 2024-12-13...
# Analyzing weather for 2024-12-13...
# Fetching data for 2024-12-14...
# Analyzing weather for 2024-12-14...
# Fetching data for 2024-12-15...
# Analyzing weather for 2024-12-15...
# Fetching data for 2024-12-16...
# Analyzing weather for 2024-12-16...
# Fetching data for 2024-12-17...
# Analyzing weather for 2024-12-17...
# Fetching data for 2024-12-18...
# Analyzing weather for 2024-12-18...
# Fetching data for 2024-12-19...
# Analyzing weather for 2024-12-19...
# Fetching data for 2024-12-20...
# Analyzing weather for 2024-12-20...
# Fetching data for 2024-12-21...
# Analyzing weather for 2024-12-21...
# Fetching data for 2024-12-22...
# Analyzing weather for 2024-12-22...
# Fetching data for 2024-12-23...
# Analyzing weather for 2024-12-23...
# Fetching data for 2024-12-24...
# Analyzing weather for 2024-12-24...
# Fetching data for 2024-12-25...
# Analyzing weather for 2024-12-25...
# Fetching data for 2024-12-26...
# Analyzing weather for 2024-12-26...
# Fetching data for 2024-12-27...
# Analyzing weather for 2024-12-27...
# Fetching data for 2024-12-28...
# Analyzing weather for 2024-12-28...
# Fetching data for 2024-12-29...
# Analyzing weather for 2024-12-29...
# Fetching data for 2024-12-30...
# Analyzing weather for 2024-12-30...
# Fetching data for 2024-12-31...
# Analyzing weather for 2024-12-31...
#
# CSV saved at: data\weather_data_hourly.csv

# %%
import csv
import os
from collections import Counter

def analyze_weather_from_csv(csv_filepath):
    """
    Reads weather data from a CSV file, calculates average temperature,
    finds the most common condition, and checks for rain.
    """
    daily_data = {}
    with open(csv_filepath, mode='r', newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            date = row['Date']
            try:
                temperature = float(row['Temperature']) if row['Temperature'] else None
            except ValueError:
                temperature = None
            condition = row['Condition']
            rain = row['Rain (yes/no)']

            if date not in daily_data:
                daily_data[date] = {'temperatures': [], 'conditions': [], 'rained': 'no'}

            if temperature is not None:
                daily_data[date]['temperatures'].append(temperature)
            if condition:
                daily_data[date]['conditions'].append(condition)
            if rain == 'yes':
                daily_data[date]['rained'] = 'yes'

    summary_data = {}
    for date, data in daily_data.items():
        avg_temp = sum(data['temperatures']) / len(data['temperatures']) if data['temperatures'] else None
        most_common_condition = Counter(data['conditions']).most_common(1)[0][0] if data['conditions'] else None
        summary_data[date] = {
            'Date': date,
            'Average Temperature': avg_temp,
            'Most Common Condition': most_common_condition,
            'Rained': data['rained']
        }
    return list(summary_data.values())  

def save_summary_to_csv(summary_data, output_csv_filepath):
    """
    Saves the analyzed weather summary data to a new CSV file.
    """
    csv_columns = ['Date', 'Average Temperature', 'Most Common Condition', 'Rained']
    try:
        with open(output_csv_filepath, mode='w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
            writer.writeheader()
            writer.writerows(summary_data)
        print(f"\nSummary data saved to: {output_csv_filepath}")
    except IOError:
        print("I/O error while writing to CSV")

input_csv_file_path = os.path.join("data", "weather_data_hourly.csv")  
output_csv_file_path = os.path.join("data", "wunderground_daily_summary_analyzed.csv")  

if os.path.exists(input_csv_file_path):
    analyzed_data_list = analyze_weather_from_csv(input_csv_file_path)
    save_summary_to_csv(analyzed_data_list, output_csv_file_path)
else:
    print(f"Input CSV file not found at: {input_csv_file_path}")
# Out:
# Summary data saved to: data\wunderground_daily_summary_analyzed.csv

# %%
# Out:
# Summary data saved to: data\wunderground_daily_summary_analyzed.csv
